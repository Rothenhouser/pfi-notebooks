# %% [markdown]
# # Dashboards
#
# Dashboards sind Kombinationen von mehreren Plots, Daten etc.
#
# Als interaktive graphische Anwendungen werden sie z.B. zur Überwachung genutzt, oder erlauben anderen Stakeholdern Zugang zu Daten und Ergebnissen bieten.

# %% [markdown]
# Eine sehr einfaches Paket für Dashboards in Python ist [Streamlit](https://streamlit.io/).
#
# Ähnlich wie bei Plotly wird auch hier eine Javascript-App generiert.

# %%
# Gapminder-Dashboard ausführen
# !python -m streamlit run gapminder-dash.py
